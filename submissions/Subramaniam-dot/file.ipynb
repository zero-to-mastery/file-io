# %%
import pandas as pd

file = pd.read_csv("/Users/subramaniamsm/Desktop/projects/file-io/spotify-2023.csv", encoding = 'ISO-8859-1')

# %%
file.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
print(f"The number of Songs in the file is {len(file)}")
# Out:
# The number of Songs in the file is 953

# %%
keys  = file['key']
count = 0 
for key in keys:
    if key == "E":
        count +=1

print(f"Number of Songs in the key of E is {count}")
# Out:
# Number of Songs in the key of E is 62

# %%
def analyze_column(col, data):
    print(f"Analysis for column name {col}")
    if data is not None and col in data.columns:
        value_counts = data[col].value_counts()
        print("Value Counts: ")
        print(value_counts.head())

        most_common_value = value_counts.idxmax()
        most_common_value_count = value_counts.max()
        print(f"\n The most common value in {col} is '{most_common_value_count}' ")
    else:
        print("Data could not be loaded or column name is incorrect")

columns_to_analyze = ['artist(s)_name', 'released_year']

for column in columns_to_analyze:
    analyze_column(column, file)
# Out:
# Analysis for column name artist(s)_name
# Value Counts:
# artist(s)_name
# Taylor Swift    34
# The Weeknd      22
# Bad Bunny       19
# SZA             19
# Harry Styles    17
# Name: count, dtype: int64
#
#  The most common value in artist(s)_name is '34'
# Analysis for column name released_year
# Value Counts:
# released_year
# 2022    402
# 2023    175
# 2021    119
# 2020     37
# 2019     36
# Name: count, dtype: int64
#
#  The most common value in released_year is '402'
