# %% [markdown]
# # Challenges
# * Write a script to identify the number of songs in the file.
# * Write a script that identify the number of songs in the key of E.
# * Count the occurrences of values in a specified column (e.g., artist names) and determine the most common value.

# %%
import pandas as pd

# %%
df = pd.read_csv("spotify-2023.csv", encoding="latin1")
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703                  43  ...  125   B  Major
# 1                 48  133716286                  48  ...   92  C#  Major
# 2                113  140003974                  94  ...  138   F  Major
# 3                100  800840817                 116  ...  170   A  Major
# 4                 50  303236322                  84  ...  144   A  Minor
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
# 2             51         32       53             17                   0
# 3             55         58       72             11                   0
# 4             65         23       80             14                  63
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
# 2          31              6
# 3          11             15
# 4          11              6
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Write a script to identify the number of songs in the file.

# %%
no_of_songs = df['track_name'].count()
print(f"Number of songs in the file: {no_of_songs}")
# Out:
# Number of songs in the file: 953

# %% [markdown]
# ## Write a script that identify the number of songs in the key of E.

# %%
key_E = df[df['key'] == 'E'].shape[0]
print(f"Number of songs in the key of E: {key_E}")
# Out:
# Number of songs in the key of E: 62

# %% [markdown]
# ## Count the occurrences of values in a specified column (e.g., artist names) and determine the most common value.

# %%
released_year = df['released_year'].value_counts()
released_year.head()
# Out:
# released_year
# 2022    402
# 2023    175
# 2021    119
# 2020     37
# 2019     36
# Name: count, dtype: int64
