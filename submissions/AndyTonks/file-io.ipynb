# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('spotify-2023.csv',encoding='latin1')
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %% [markdown]
# ## Challenges
# # Write a script to identify the number of songs in the file.

# %%
songcount = df['track_name'].count()
print(f'Number of songs in file:= {songcount}')
# Out:
# Number of songs in file:= 953

# %% [markdown]
# # Write a script that identify the number of songs in the key of E.

# %%
keyE = df.loc[df['key'] == 'E']
cnt = keyE['track_name'].count()
print(f'Number of songs in the key of E = {cnt}')
print('Listed below song in Key of E')
keyE
# Out:
# Number of songs in the key of E = 62
# Listed below song in Key of E
#                                 track_name                  artist(s)_name  \
# 33                               Anti-Hero                    Taylor Swift
# 34                                     TQG                Karol G, Shakira
# 54                            Another Love                       Tom Odell
# 76                            Here With Me                            d4vd
# 103                            Mockingbird                          Eminem
# ..                                     ...                             ...
# 921                                   Nxde                        (G)I-DLE
# 932  Pussy & Millions (feat. Travis Scott)  Drake, Travis Scott, 21 Savage
# 933                         Vigilante Shit                    Taylor Swift
# 936                             Mastermind                    Taylor Swift
# 952                                  Alone                       Burna Boy
#
# ...

# %% [markdown]
# # Count the occurrences of values in a specified column (e.g., artist names) and determine the most common value.

# %%
x = df['artist(s)_name'].value_counts()
sns.set_theme('paper')
plt.figure(figsize=(10,6))
x = x[:20]
sns.barplot(x,color='g')
plt.title('Top 20 Artists')
plt.xticks(rotation =90)

x
# Out:
# artist(s)_name
# Taylor Swift        34
# The Weeknd          22
# Bad Bunny           19
# SZA                 19
# Harry Styles        17
# Kendrick Lamar      12
# Morgan Wallen       11
# Ed Sheeran           9
# BTS                  8
# Feid                 8
# Drake, 21 Savage     8
# Labrinth             7
# Olivia Rodrigo       7
# NewJeans             6
# Doja Cat             6
# Billie Eilish        5
# Drake                4
# IVE                  4
# Arctic Monkeys       4
# Karol G              4
# Name: count, dtype: int64
