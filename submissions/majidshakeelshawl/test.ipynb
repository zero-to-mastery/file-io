# %%
import pandas as pd

songs = pd.read_csv("./spotify-2023.csv", encoding="ISO-8859-1")

songs_key_E = songs[songs["key"] == "E"]
songs_key_E.head()
# len(songs)
# Out:
#        track_name    artist(s)_name  artist_count  released_year  \
# 33      Anti-Hero      Taylor Swift             1           2022
# 34            TQG  Karol G, Shakira             2           2023
# 54   Another Love         Tom Odell             1           2012
# 76   Here With Me              d4vd             1           2022
# 103   Mockingbird            Eminem             1           2004
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 33               10            21                  9082                 56
# 34                2            23                  4284                 49
# 54               10            15                 18371                 83
# 76                7            17                  3246                 23
# 103               1             1                 12985                 61
#
#         streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# ...
